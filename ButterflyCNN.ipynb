# %% [markdown]
# <a href="https://colab.research.google.com/github/BHANAPEESHAN/CNN_Projects_/blob/main/ButterflyCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ['KAGGLE_USERNAME']="bhanapeeshan"
os.environ['KAGGLE_KEY']="646853511eaba7e71ae9a0d4d3c4af8a"
# !kaggle datasets download -d gpiosenka/butterfly-images40-species
# Out:
# Downloading butterfly-images40-species.zip to /content
#  99% 362M/365M [00:15<00:00, 22.0MB/s]
# 100% 365M/365M [00:15<00:00, 24.1MB/s]

# %%
from zipfile import ZipFile
file_name = "/content/butterfly-images40-species.zip"
with ZipFile(file_name,'r') as zip:
  zip.extractall()
  print('done')
# Out:
# done

# %%
import warnings
warnings.filterwarnings('ignore')
data_dir_list=os.listdir("/content/train")
print(data_dir_list)
path,dirs,files=next(os.walk("/content/train"))
file_count=len(files)
# Out:
# ['GREEN CELLED CATTLEHEART', 'COMMON BANDED AWL', 'EASTERN PINE ELFIN', 'MOURNING CLOAK', 'IPHICLUS SISTER', 'EASTERN COMA', 'SOUTHERN DOGFACE', 'LARGE MARBLE', 'BLUE SPOTTED CROW', 'MALACHITE', 'ATALA', 'ORANGE OAKLEAF', 'CHESTNUT', 'ZEBRA LONG WING', 'COMMON WOOD-NYMPH', 'ADONIS', 'RED CRACKER', 'VICEROY', 'MANGROVE SKIPPER', 'SCARCE SWALLOW', 'GREY HAIRSTREAK', 'CRECENT', 'CLOUDED SULPHUR', 'CABBAGE WHITE', 'WOOD SATYR', 'PEACOCK', 'ORANGE TIP', 'PIPEVINE SWALLOW', 'POPINJAY', 'MILBERTS TORTOISESHELL', 'AFRICAN GIANT SWALLOWTAIL', 'CHECQUERED SKIPPER', 'RED SPOTTED PURPLE', 'SLEEPY ORANGE', 'BECKERS WHITE', 'MESTRA', 'SOOTYWING', 'TWO BARRED FLASHER', 'METALMARK', 'MONARCH', 'CLODIUS PARNASSIAN', 'YELLOW SWALLOW TAIL', 'SILVER SPOT SKIPPER', 'RED POSTMAN', 'GREAT JAY', 'EASTERN DAPPLE WHITE', 'DANAID EGGFLY', 'CAIRNS BIRDWING', 'PAINTED LADY', 'QUESTION MARK', 'PURPLISH COPPER', 'CLEOPATRA', 'BROWN SIPROETA', 'BLUE MORPHO', 'APPOLLO', 'PINE WHITE', 'AMERICAN SNOOT', 'CRIMSON PATCH', 'INDRA SWALLOW', 'TROPICAL LEAFWING', 'PURPLE HAIRSTREAK', 'COPPER TAIL', 'GREAT EGGFLY', 'BANDED ORANGE HELICONIAN', 'ELBOWED PIERROT', 'GOLD BANDED', 'JULIA', 'RED ADMIRAL', 'PAPER KITE', 'ULYSES', 'BANDED PEACOCK', 'STRAITED QUEEN', 'AN 88', 'BLACK HAIRSTREAK', 'ORCHARD SWALLOW']

# %%
import os
import numpy as np
import shutil
import random

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
from matplotlib.image import imread
import pathlib


image_folder=['GREEN CELLED CATTLEHEART', 'COMMON BANDED AWL', 'EASTERN PINE ELFIN', 'MOURNING CLOAK', 'IPHICLUS SISTER', 'EASTERN COMA', 'SOUTHERN DOGFACE', 'LARGE MARBLE', 'BLUE SPOTTED CROW', 'MALACHITE', 'ATALA', 'ORANGE OAKLEAF', 'CHESTNUT', 'ZEBRA LONG WING', 'COMMON WOOD-NYMPH', 'ADONIS', 'RED CRACKER', 'VICEROY', 'MANGROVE SKIPPER', 'SCARCE SWALLOW', 'GREY HAIRSTREAK', 'CRECENT', 'CLOUDED SULPHUR', 'CABBAGE WHITE', 'WOOD SATYR', 'PEACOCK', 'ORANGE TIP', 'PIPEVINE SWALLOW', 'POPINJAY', 'MILBERTS TORTOISESHELL', 'AFRICAN GIANT SWALLOWTAIL', 'CHECQUERED SKIPPER', 'RED SPOTTED PURPLE', 'SLEEPY ORANGE', 'BECKERS WHITE', 'MESTRA', 'SOOTYWING', 'TWO BARRED FLASHER', 'METALMARK', 'MONARCH', 'CLODIUS PARNASSIAN', 'YELLOW SWALLOW TAIL', 'SILVER SPOT SKIPPER', 'RED POSTMAN', 'GREAT JAY', 'EASTERN DAPPLE WHITE', 'DANAID EGGFLY', 'CAIRNS BIRDWING', 'PAINTED LADY', 'QUESTION MARK', 'PURPLISH COPPER', 'CLEOPATRA', 'BROWN SIPROETA', 'BLUE MORPHO', 'APPOLLO', 'PINE WHITE', 'AMERICAN SNOOT', 'CRIMSON PATCH', 'INDRA SWALLOW', 'TROPICAL LEAFWING', 'PURPLE HAIRSTREAK', 'COPPER TAIL', 'GREAT EGGFLY', 'BANDED ORANGE HELICONIAN', 'ELBOWED PIERROT', 'GOLD BANDED', 'JULIA', 'RED ADMIRAL', 'PAPER KITE', 'ULYSES', 'BANDED PEACOCK', 'STRAITED QUEEN', 'AN 88', 'BLACK HAIRSTREAK', 'ORCHARD SWALLOW']
nimgs={}

for i in image_folder:
  nimages=len(os.listdir('/content/train/'+i+'/'))
  nimgs[i]=nimages
plt.figure(figsize=(100,50))
plt.bar(range(len(nimgs)),list(nimgs.values()),align='center')
plt.xticks(range(len(nimgs)),list(nimgs.keys()))
plt.title("Distribution of classes in train",)
plt.show()

# %%
for i in image_folder:
  print("training images of {} are: ".format(i)+ str(len(os.listdir("/content/train/"+i+"/"))))
# Out:
# training images of GREEN CELLED CATTLEHEART are: 126
# training images of COMMON BANDED AWL are: 125
# training images of EASTERN PINE ELFIN are: 136
# training images of MOURNING CLOAK are: 187
# training images of IPHICLUS SISTER are: 136
# training images of EASTERN COMA are: 133
# training images of SOUTHERN DOGFACE are: 125
# training images of LARGE MARBLE are: 116
# training images of BLUE SPOTTED CROW are: 123
# training images of MALACHITE are: 104
# training images of ATALA are: 143
# training images of ORANGE OAKLEAF are: 125
# training images of CHESTNUT are: 122
# training images of ZEBRA LONG WING are: 108
# training images of COMMON WOOD-NYMPH are: 128
# training images of ADONIS are: 126
# training images of RED CRACKER are: 137
# training images of VICEROY are: 115
# training images of MANGROVE SKIPPER are: 125
# training images of SCARCE SWALLOW are: 139
# training images of GREY HAIRSTREAK are: 123
# training images of CRECENT are: 138
# training images of CLOUDED SULPHUR are: 131
# training images of CABBAGE WHITE are: 128
# training images of WOOD SATYR are: 102
# training images of PEACOCK are: 120
# training images of ORANGE TIP are: 137
# training images of PIPEVINE SWALLOW are: 120
# training images of POPINJAY are: 121
# training images of MILBERTS TORTOISESHELL are: 137
# training images of AFRICAN GIANT SWALLOWTAIL are: 107
# training images of CHECQUERED SKIPPER are: 136
# training images of RED SPOTTED PURPLE are: 123
# training images of SLEEPY ORANGE are: 153
# training images of BECKERS WHITE are: 116
# training images of MESTRA are: 123
# training images of SOOTYWING are: 128
# training images of TWO BARRED FLASHER are: 109
# training images of METALMARK are: 108
# training images of MONARCH are: 129
# training images of CLODIUS PARNASSIAN are: 124
# training images of YELLOW SWALLOW TAIL are: 107
# training images of SILVER SPOT SKIPPER are: 119
# training images of RED POSTMAN are: 127
# training images of GREAT JAY are: 135
# training images of EASTERN DAPPLE WHITE are: 132
# training images of DANAID EGGFLY are: 135
# training images of CAIRNS BIRDWING are: 118
# training images of PAINTED LADY are: 112
# training images of QUESTION MARK are: 110
# training images of PURPLISH COPPER are: 132
# training images of CLEOPATRA are: 133
# training images of BROWN SIPROETA are: 141
# training images of BLUE MORPHO are: 107
# training images of APPOLLO are: 128
# training images of PINE WHITE are: 123
# training images of AMERICAN SNOOT are: 105
# training images of CRIMSON PATCH are: 103
# training images of INDRA SWALLOW are: 115
# training images of TROPICAL LEAFWING are: 118
# training images of PURPLE HAIRSTREAK are: 113
# training images of COPPER TAIL are: 134
# training images of GREAT EGGFLY are: 111
# training images of BANDED ORANGE HELICONIAN are: 139
# training images of ELBOWED PIERROT are: 117
# training images of GOLD BANDED are: 104
# training images of JULIA are: 115
# training images of RED ADMIRAL are: 117
# training images of PAPER KITE are: 129
# training images of ULYSES are: 120
# training images of BANDED PEACOCK are: 119
# training images of STRAITED QUEEN are: 124
# training images of AN 88 are: 121
# training images of BLACK HAIRSTREAK are: 121
# training images of ORCHARD SWALLOW are: 109

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense,Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint

# %%
img_width=256
img_height=256
batch_size=32

# %%
TRAINING_DIR = "/content/train"
train_datagen=ImageDataGenerator(rescale=1/255.0)
train_gen=train_datagen.flow_from_directory(TRAINING_DIR,
                                            batch_size=batch_size,
                                            class_mode='categorical',
                                            target_size=(img_height,img_width))
# Out:
# Found 9285 images belonging to 75 classes.

# %%
VALIDATION_DIR = "/content/valid"
val_datagen=ImageDataGenerator(rescale=1/255.0)
val_gen=val_datagen.flow_from_directory(VALIDATION_DIR,
                                            batch_size=batch_size,
                                            class_mode='categorical',
                                            target_size=(img_height,img_width))
# Out:
# Found 375 images belonging to 75 classes.

# %%
callbacks=EarlyStopping(monitor='val_loss',patience=5,verbose=1,mode='min')    #'auto'
bestmodelfile='/content/CNN_aug_best_weights.h5'
bestmodel=ModelCheckpoint(bestmodelfile,monitor='val_acc',verbose=1,save_best_only=True)

# %%
model = Sequential([
    Conv2D(16, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)), 
    MaxPooling2D(2, 2),
    Conv2D(32, (3, 3), activation='relu'), 
    MaxPooling2D(2, 2),
    Dropout(0.5),
    Conv2D(64, (3, 3), activation='relu'),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2,2),
    Dropout(0.5),
    Conv2D(128, (3, 3), activation='relu'),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2,2),
    Dropout(0.5),
    Flatten(),
    Dense(256, activation='relu'),
    Dense(256, activation='relu'),
    Dense(75, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 254, 254, 16)      448
#
#  max_pooling2d_14 (MaxPoolin  (None, 127, 127, 16)     0
#  g2D)
#
#  conv2d_21 (Conv2D)          (None, 125, 125, 32)      4640
#
#  max_pooling2d_15 (MaxPoolin  (None, 62, 62, 32)       0
#  g2D)
#
#  dropout_9 (Dropout)         (None, 62, 62, 32)        0
#
#  conv2d_22 (Conv2D)          (None, 60, 60, 64)        18496
#
#  conv2d_23 (Conv2D)          (None, 58, 58, 64)        36928
#
#  max_pooling2d_16 (MaxPoolin  (None, 29, 29, 64)       0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 29, 29, 64)        0
#
#  conv2d_24 (Conv2D)          (None, 27, 27, 128)       73856
#
#  conv2d_25 (Conv2D)          (None, 25, 25, 128)       147584
#
#  max_pooling2d_17 (MaxPoolin  (None, 12, 12, 128)      0
#  g2D)
#
#  dropout_11 (Dropout)        (None, 12, 12, 128)       0
#
#  flatten_4 (Flatten)         (None, 18432)             0
#
#  dense_12 (Dense)            (None, 256)               4718848
#
#  dense_13 (Dense)            (None, 256)               65792
#
#  dense_14 (Dense)            (None, 75)                19275
#
# =================================================================
# Total params: 5,085,867
# Trainable params: 5,085,867
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow import optimizers
model.compile(optimizer=optimizers.Adam(learning_rate=0.0001), 
              loss='binary_crossentropy', 
              metrics =['accuracy'])

# %%
history = model.fit_generator(train_gen,epochs=10,verbose=1,validation_data=val_gen,callbacks=[bestmodel])
